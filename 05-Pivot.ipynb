# %% [markdown]
# # Jeux de données de l’OFROU dans des fichiers texte
#
# [Page d’information sur les jeux de données](https://www.astra.admin.ch/astra/fr/home/documentation/donnees-et-produits-information/donnees-relatives-aux-vehicules.html)
#
# [Répertoire où est situé le fichier qu’on va utiliser](https://opendata.astra.admin.ch/ivzod/1000-Fahrzeuge_IVZ/1300-Fahrzeugbestaende/1320-Datensaetze_monatlich/)
#
# Dans ce notebook, je vous montre comment ouvrir un tel jeu de données avec Python avec la bibliothèque logicielle «Pandas». On apprendra les bases de Pandas dans un second temps.

# %%
import pandas as pd

# %%
# Cette cellule prend 30 secondes, voir plus,
# parce que le fichier est lourd (plus de 200 Mo)
# df = pd.read_csv(
#     "https://opendata.astra.admin.ch/ivzod/1000-Fahrzeuge_IVZ/1300-Fahrzeugbestaende/1320-Datensaetze_monatlich/BEST_MOTO.txt",
#     sep="\t",
# )
df = pd.read_csv("data/motos.csv")

# %%
df.iloc[0]
# Out:
# Unnamed: 0                          0
# Fahrzeugklasse                     L3
# Fahrzeugart_Code                   60
# Fahrzeugart                  Motorrad
# Marken_Code                      5590
#                               ...
# Inverkehrsetzung_Kanton            SO
# PLZ                              46..
# Staat_Code                         CH
# Staat                         Schweiz
# Datenstand                 01.11.2024
# Name: 0, Length: 65, dtype: object

# %%
df.pivot_table(index="Marke", columns="Fahrzeugart", aggfunc="count")
# Out:
#                                Achsen                                   \
# Fahrzeugart   Dreirädr. Motorfahrzeug Kleinmotorfahrzeug Kleinmotorrad
# Marke
# AB KAWASAKI                       NaN              274.0           NaN
# ABAT                              NaN                NaN           2.0
# AC-COBRA                          NaN                NaN           NaN
# ACADIAN                           NaN                NaN           NaN
# ACCESS                            NaN              125.0           NaN
# ...                               ...                ...           ...
# ZNEN                              NaN                NaN          39.0
# ZONGSHEN                          NaN                NaN           2.0
# ZONTES                            NaN                NaN           NaN
# ZUENDAPP                          NaN                NaN          29.0
# ZWEIRAD-UNION                     NaN                NaN          10.0
#
# ...

# %%
df["PLZ"].mean()

# %%
df["Fahrzeugart_Code"]

# %%
# Le début des données
df.head(20)
# Out:
#    Fahrzeugklasse  Fahrzeugart_Code Fahrzeugart  Marken_Code     Marke  \
# 0              L3                60    Motorrad         5590   ACADIAN
# 1              L3                60    Motorrad         5087  AC-COBRA
# 2              L3                60    Motorrad         4363       ACO
# 3              L3                60    Motorrad         3382     ADIVA
# 4              L3                60    Motorrad         3992     ADIVA
# 5              L3                60    Motorrad         3382     ADIVA
# 6             NaN                60    Motorrad         3382     ADIVA
# 7             NaN                60    Motorrad         3382     ADIVA
# 8             NaN                60    Motorrad         3382     ADIVA
# 9              L3                60    Motorrad         3382     ADIVA
# 10             L3                60    Motorrad         3382     ADIVA
# 11             L3                60    Motorrad         3382     ADIVA
# ...

# %%
df["Marke"].value_counts()
# Out:
# Marke
# YAMAHA             133979
# HONDA              128187
# PIAGGIO            102440
# BMW                 60305
# HARLEY-DAVIDSON     49251
#                     ...
# CHIHUI                  1
# DAIMLER                 1
# E-BIKEBOARD             1
# EBRETTI                 1
# SEAT                    1
# Name: count, Length: 768, dtype: int64
